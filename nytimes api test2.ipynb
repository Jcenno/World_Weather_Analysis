# %%
import requests

# %%
from pprint import pprint

# %%
apiKey = "1Z0PI7e2stFa3D8aAhNIMmHLrUJvlXgd"

# %%
exampleApiCallURL=f"https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key={apiKey}"

# %%
response = requests.get(exampleApiCallURL)

# %%
pprint(response.status_code)
# Out:
# 200

# %%
pprint(response.json())
# Out:
# {'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights '
#               'Reserved.',
#  'last_modified': '2021-05-19T22:10:46-04:00',
#  'num_results': 15,
#  'results': {'bestsellers_date': '2021-05-15',
#              'books': [{'age_group': '',
#                         'amazon_product_url': 'https://www.amazon.com/dp/0385546572?tag=NYTBSREV-20',
#                         'article_chapter_link': '',
#                         'asterisk': 0,
#                         'author': 'Stacey Abrams',
#                         'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780385546577.jpg',
#                         'book_image_height': 500,
#                         'book_image_width': 333,
#                         'book_review_link': '',
#                         'book_uri': 'nyt://book/cef54ed8-224a-5c72-989c-96b413c287d0',
#                         'buy_links': [{'name': 'Amazon',
# ...
