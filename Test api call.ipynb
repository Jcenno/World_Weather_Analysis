# %%
apiKey= "26e1565cd63d833745cdc6ddd3073b3b"

# %%
currentWeatherUlr=f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={apiKey}"

# %%
exampleApiCallURL=f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={apiKey}"

# %%
import requests

# %%
from pprint import pprint

# %%
response = requests.get(exampleApiCallURL)

# %%
pprint(response.status_code)
# Out:
# 200

# %%
pprint(response.json())
# Out:
# {'city': {'coord': {'lat': 55.7522, 'lon': 37.6156},
#           'country': 'RU',
#           'id': 524901,
#           'name': 'Moscow',
#           'population': 0,
#           'sunrise': 1621904513,
#           'sunset': 1621965084,
#           'timezone': 10800},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 86},
#            'dt': 1621911600,
#            'dt_txt': '2021-05-25 03:00:00',
#            'main': {'feels_like': 282.18,
#                     'grnd_level': 1005,
#                     'humidity': 67,
#                     'pressure': 1022,
#                     'sea_level': 1022,
#                     'temp': 283.35,
#                     'temp_kf': -1.44,
#                     'temp_max': 284.79,
#                     'temp_min': 283.35},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
# ...
